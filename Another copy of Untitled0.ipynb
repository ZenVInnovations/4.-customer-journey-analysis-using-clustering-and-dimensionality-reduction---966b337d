# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn umap-learn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import umap
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# # New Section

# %%
df=pd.read_csv('/Boston.csv')

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 101.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 6.0 MB/s eta 0:00:00
# ...

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  506 non-null    int64
#  1   crim        506 non-null    float64
#  2   zn          506 non-null    float64
#  3   indus       506 non-null    float64
#  4   chas        506 non-null    int64
#  5   nox         506 non-null    float64
#  6   rm          506 non-null    float64
#  7   age         506 non-null    float64
#  8   dis         506 non-null    float64
#  9   rad         506 non-null    int64
#  10  tax         506 non-null    int64
#  11  ptratio     506 non-null    float64
#  12  black       506 non-null    float64
#  13  lstat       506 non-null    float64
#  14  medv        506 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 59.4 KB
#        Unnamed: 0        crim          zn       indus        chas         nox  \
# ...

# %%
st.little

# %%
# Handle missing values
df.fillna(0, inplace=True)

# Encode categorical variables if any (Label Encoding or One-hot Encoding)
df_encoded = pd.get_dummies(df)

# Normalize/scale features
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_encoded)

# %%
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_scaled)

plt.scatter(pca_result[:, 0], pca_result[:, 1])
plt.title("PCA Projection")
plt.show()

# %%
# Install necessary packages
# !pip install pandas scikit-learn plotly umap-learn streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 38.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 3.6 MB/s eta 0:00:00

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load your dataset
df = pd.read_csv('/content/1000_ml_jobs_us.csv')

# %%
df.fillna(0, inplace=True)
X = df.drop(columns=['company_website', 'company_description'])

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-14d4e236ab68> in <cell line: 0>()
#       1 scaler = StandardScaler()
# ----> 2 X_scaled = scaler.fit_transform(X)
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     317     @wraps(f)
#     318     def wrapped(self, X, *args, **kwargs):
# --> 319         data_to_wrap = f(self, X, *args, **kwargs)
#     320         if isinstance(data_to_wrap, tuple):
#     321             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     916         if y is None:
#     917             # fit method of arity 1 (unsupervised transformation)
# --> 918             return self.fit(X, **fit_params).transform(X)
#     919         else:
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                   int64
# job_posted_date             object
# company_address_locality    object
# company_address_region      object
# company_name                object
# company_website             object
# company_description         object
# job_description_text        object
# seniority_level             object
# job_title                   object
# dtype: object

# %%
# Drop unnecessary text-based columns
df = df.drop(columns=['company_website', 'company_description'], errors='ignore')

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'], errors='coerce')
df['days_since_posted'] = (pd.to_datetime('today') - df['job_posted_date']).dt.days

# %%
from sklearn.preprocessing import LabelEncoder

for col in ['seniority_level', 'job_title', 'company_address_region']:

    df[col] = df[col].astype(str)  # ensure all are string

    le = LabelEncoder()

    df[col] = le.fit_transform(df[col])

# %%
df = df.drop(columns=[
    'company_description',
    'job_description_text',
    'company_website',
    'company_name'
], errors='ignore')

# %%
# !pip install umap-learn -q

import umap

# %%
# !pip install umap-learn -q

# %%
from sklearn.preprocessing import StandardScaler

# Replace with your actual numeric features
X = df[['days_since_posted', 'seniority_level', 'job_title', 'company_address_region']].fillna(0)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
